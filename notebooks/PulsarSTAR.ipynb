# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = '/content/drive/My Drive/Colab Notebooks/HTRU_2.csv'

# %%
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#      140.5625  55.68378214  -0.234571412  -0.699648398  3.199832776  \
# 0  102.507812    58.882430      0.465318     -0.515088     1.677258
# 1  103.015625    39.341649      0.323328      1.051164     3.121237
# 2  136.750000    57.178449     -0.068415     -0.636238     3.642977
# 3   88.726562    40.672225      0.600866      1.123492     1.178930
# 4   93.570312    46.698114      0.531905      0.416721     1.636288
#
#    19.11042633  7.975531794  74.24222492  0
# 0    14.860146    10.576487   127.393580  0
# 1    21.744669     7.735822    63.171909  0
# 2    20.959280     6.896499    53.593661  0
# 3    11.468720    14.269573   252.567306  0
# 4    14.545074    10.621748   131.394004  0

# %%
df = pd.DataFrame(data)

columns = ['Mean P', 'StD P', 'Kurtosis P', 'Skewness P',
               'Mean DM_SNR', 'StD DM_SNR', 'Kurtosis DM_SNR', 'Skewness DM_SNR', 'Target']
data.rename(columns=dict(zip(data.columns, columns)), inplace=True)

df.head()
# Out:
#        Mean P      StD P  Kurtosis P  Skewness P  Mean DM_SNR  StD DM_SNR  \
# 0  102.507812  58.882430    0.465318   -0.515088     1.677258   14.860146
# 1  103.015625  39.341649    0.323328    1.051164     3.121237   21.744669
# 2  136.750000  57.178449   -0.068415   -0.636238     3.642977   20.959280
# 3   88.726562  40.672225    0.600866    1.123492     1.178930   11.468720
# 4   93.570312  46.698114    0.531905    0.416721     1.636288   14.545074
#
#    Kurtosis DM_SNR  Skewness DM_SNR  Target
# 0        10.576487       127.393580       0
# 1         7.735822        63.171909       0
# 2         6.896499        53.593661       0
# 3        14.269573       252.567306       0
# 4        10.621748       131.394004       0

# %%
df.info()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17897 entries, 0 to 17896
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Mean P           17897 non-null  float64
#  1   StD P            17897 non-null  float64
#  2   Kurtosis P       17897 non-null  float64
#  3   Skewness P       17897 non-null  float64
#  4   Mean DM_SNR      17897 non-null  float64
#  5   StD DM_SNR       17897 non-null  float64
#  6   Kurtosis DM_SNR  17897 non-null  float64
#  7   Skewness DM_SNR  17897 non-null  float64
#  8   Target           17897 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB
# Mean P             0
# StD P              0
# Kurtosis P         0
# Skewness P         0
# Mean DM_SNR        0
# StD DM_SNR         0
# Kurtosis DM_SNR    0
# Skewness DM_SNR    0
# Target             0
# dtype: int64

# %%
df.describe()
# Out:
#              Mean P         StD P    Kurtosis P    Skewness P   Mean DM_SNR  \
# count  17897.000000  17897.000000  17897.000000  17897.000000  17897.000000
# mean     111.078321     46.549021      0.477897      1.770417     12.614926
# std       25.652705      6.843040      1.064056      6.168058     29.473637
# min        5.812500     24.772042     -1.876011     -1.791886      0.213211
# 25%      100.929688     42.375426      0.027108     -0.188528      1.923077
# 50%      115.078125     46.946435      0.223241      0.198736      2.801839
# 75%      127.085938     51.022887      0.473349      0.928206      5.464883
# max      192.617188     98.778911      8.069522     68.101622    223.392141
#
#          StD DM_SNR  Kurtosis DM_SNR  Skewness DM_SNR       Target
# count  17897.000000     17897.000000     17897.000000  17897.00000
# mean      26.326918         8.303574       104.859419      0.09158
# std       19.471042         4.506217       106.517270      0.28844
# ...

# %%
pulsar = df[df['Target'] == 1]
pulsar_count = pulsar['Target'].count()
not_pulsar = df[df['Target'] == 0]
not_pulsar_count = not_pulsar['Target'].count()
print(pulsar_count, not_pulsar_count)
# Out:
# 1639 16258

# %%
plt.figure(figsize=(2,2))
plt.pie(df["Target"].value_counts(), autopct="%1.1f%%")
plt.show()

# %%
df.corr()
# Out:
#                    Mean P     StD P  Kurtosis P  Skewness P  Mean DM_SNR  \
# Mean P           1.000000  0.547099   -0.873899   -0.738780    -0.298832
# StD P            0.547099  1.000000   -0.521418   -0.539792     0.006893
# Kurtosis P      -0.873899 -0.521418    1.000000    0.945730     0.414362
# Skewness P      -0.738780 -0.539792    0.945730    1.000000     0.412052
# Mean DM_SNR     -0.298832  0.006893    0.414362    0.412052     1.000000
# StD DM_SNR      -0.307005 -0.047606    0.432873    0.415135     0.796554
# Kurtosis DM_SNR  0.234345  0.029436   -0.341216   -0.328846    -0.615974
# Skewness DM_SNR  0.144057  0.027714   -0.214505   -0.204790    -0.354276
# Target          -0.673187 -0.363704    0.791592    0.709526     0.400873
#
#                  StD DM_SNR  Kurtosis DM_SNR  Skewness DM_SNR    Target
# Mean P            -0.307005         0.234345         0.144057 -0.673187
# StD P             -0.047606         0.029436         0.027714 -0.363704
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(), annot=True, fmt='.0%')
# Out:
# <Axes: >

# %%
df.iloc[:, 0:9].corr()
# Out:
#                    Mean P     StD P  Kurtosis P  Skewness P  Mean DM_SNR  \
# Mean P           1.000000  0.547099   -0.873899   -0.738780    -0.298832
# StD P            0.547099  1.000000   -0.521418   -0.539792     0.006893
# Kurtosis P      -0.873899 -0.521418    1.000000    0.945730     0.414362
# Skewness P      -0.738780 -0.539792    0.945730    1.000000     0.412052
# Mean DM_SNR     -0.298832  0.006893    0.414362    0.412052     1.000000
# StD DM_SNR      -0.307005 -0.047606    0.432873    0.415135     0.796554
# Kurtosis DM_SNR  0.234345  0.029436   -0.341216   -0.328846    -0.615974
# Skewness DM_SNR  0.144057  0.027714   -0.214505   -0.204790    -0.354276
# Target          -0.673187 -0.363704    0.791592    0.709526     0.400873
#
#                  StD DM_SNR  Kurtosis DM_SNR  Skewness DM_SNR    Target
# Mean P            -0.307005         0.234345         0.144057 -0.673187
# StD P             -0.047606         0.029436         0.027714 -0.363704
# ...
